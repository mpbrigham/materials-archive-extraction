# %% [markdown]
# # LLM Agent V1 - Metadata Extraction Notebook
#
# This notebook demonstrates the full flow:
# - Uploading a supplier PDF
# - Extracting text using `process_pdf.py`
# - Sending to LLM for structured JSON extraction

# %%
# !python ../pdf_ingest/process_pdf.py ../samples/ceramic_brochure.pdf > extracted_text.txt

# %%
# Insert extracted text into the V1 prompt (manually or via API call)
with open("extracted_text.txt") as f:
    input_text = f.read()

print("Send this to your LLM with the AGENT_PROMPT.txt schema:")
print(input_text[:1000])
